# %% [markdown]
# Define Variables and imports

# %%
import yfinance as yf
import datetime as dt
import pandas as pd
import numpy as np
import time

# Set up the start and end dates for the data
start_date = '2020-01-02'
end_date = '2023-04-04'

# Set up the ticker symbols for TQQQ and SQQQ
tqqq_symbol = 'TQQQ'
sqqq_symbol = 'SQQQ'

portfolio_df = pd.DataFrame(columns=['Week End Date','TQQQ Call Sell Price', 'SQQQ Put Sell Price', 'Total Cost', 'Total P/L'])
# Set up the options expiration date as the third Friday of each month
def get_third_friday(year, month):
    d = dt.date(year, month, 15)
    while d.weekday() != 4:
        d += dt.timedelta(1)
    return d

# Set up the strike prices and width of the spreads
spread_width = 0.05
tqqq_strike_price = 0
sqqq_strike_price = 0

# Set up the initial portfolio value
initial_portfolio_value = 10000

# %% [markdown]
# Define a function to calculate the profit/loss of a trade

# %%
def calculate_profit_loss(quantity, buy_price, sell_price):
    return quantity * (sell_price - buy_price)

# Set up an empty list to store the portfolio values over time
portfolio_values = []

# %% [markdown]
# Download the historical data for TQQQ and SQQQ

# %%
tqqq_data = yf.download(tqqq_symbol, start=start_date, end=end_date)
sqqq_data = yf.download(sqqq_symbol, start=start_date, end=end_date)

spread_width = 0.05  # Set the spread width for the call and put spreads
tqqq_data['Strike'] = round(tqqq_data['Close'] / spread_width) * spread_width
sqqq_data['Strike'] = round(sqqq_data['Close'] / spread_width) * spread_width
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
#display Data
tqqq_data
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2020-01-02  22.177500  22.709999  22.055000  22.709999  22.461794   65536000
# 2020-01-03  21.822500  22.500000  21.809999  22.092501  21.851044   72590000
# 2020-01-06  21.567499  22.520000  21.487499  22.512501  22.266453   64047600
# 2020-01-07  22.535000  22.695000  22.290001  22.485001  22.239254   53849600
# 2020-01-08  22.490000  23.320000  22.382500  23.002501  22.751099   79582400
# ...               ...        ...        ...        ...        ...        ...
# 2023-03-28  25.139999  25.139999  24.290001  24.870001  24.870001  118020700
# 2023-03-29  25.760000  26.370001  25.570000  26.230000  26.230000  119365300
# 2023-03-30  26.820000  27.090000  26.490000  26.940001  26.940001  130150000
# 2023-03-31  27.000000  28.320000  26.910000  28.260000  28.260000  126571300
# 2023-04-03  27.680000  28.120001  27.330000  28.059999  28.059999  124678300
#
#             Strike
# Date
# 2020-01-02   22.70
# 2020-01-03   22.10
# 2020-01-06   22.50
# 2020-01-07   22.50
# 2020-01-08   23.00
# ...            ...
# 2023-03-28   24.85
# 2023-03-29   26.25
# 2023-03-30   26.95
# 2023-03-31   28.25
# 2023-04-03   28.05
#
# [819 rows x 7 columns]

# %%
sqqq_data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  546.000000  549.250000  532.500000  532.500000  526.091980
# 2020-01-03  553.250000  553.500000  537.250000  546.750000  540.170532
# 2020-01-06  559.750000  561.750000  536.250000  536.250000  529.796875
# 2020-01-07  535.750000  541.750000  532.000000  536.500000  530.043823
# 2020-01-08  537.000000  539.500000  517.250000  524.500000  518.188232
# ...                ...         ...         ...         ...         ...
# 2023-03-28   33.220001   34.320000   33.220001   33.549999   33.549999
# 2023-03-29   32.340000   32.619999   31.540001   31.760000   31.760000
# 2023-03-30   31.020000   31.410000   30.680000   30.879999   30.879999
# 2023-03-31   30.830000   30.910000   29.290001   29.360001   29.360001
# 2023-04-03   29.950001   30.330000   29.500000   29.559999   29.559999
#
#                Volume  Strike
# Date
# 2020-01-02     644972  532.50
# 2020-01-03     728464  546.75
# 2020-01-06     627520  536.25
# 2020-01-07     442268  536.50
# 2020-01-08     730600  524.50
# ...               ...     ...
# 2023-03-28  110031400   33.55
# 2023-03-29  120130400   31.75
# 2023-03-30  115341700   30.90
# 2023-03-31  139274800   29.35
# 2023-04-03  110679000   29.55
#
# [819 rows x 7 columns]

# %% [markdown]
# Loop over each month in the data and buy the call and put spreads on the third Friday

# %%
# Loop over each month in the data and buy the call and put spreads on the third Friday
for year in range(int(start_date[:4]), int(end_date[:4])+1):
    i= 0
    for month in range(1, 13):
        if year == int(start_date[:4]) and month < int(start_date[5:7]):
            continue
        if year == int(end_date[:4]) and month > int(end_date[5:7]):
            continue

        # Get the expiration date for this month
        expiration_date = get_third_friday(year, month)

        # Only execute the trade on Fridays
        if expiration_date.weekday() != 4:
            continue

        # Get the data for this month
        # tqqq_month_data = tqqq_data.loc[start_date:end_date][str(year)+'-'+str(month)]
        # sqqq_month_data = sqqq_data.loc[start_date:end_date][str(year)+'-'+str(month)]
       # tqqq_month_data = tqqq_data.loc[start_date:end_date][pd.to_datetime(str(year)+'-'+str(month))]
        #sqqq_month_data = sqqq_data.loc[start_date:end_date][pd.to_datetime(str(year)+'-'+str(month))]
        # Get the data for this month
        month_start = pd.to_datetime(str(year)+'-'+str(month)+'-01')
        month_end = month_start + pd.DateOffset(months=1) - pd.Timedelta(days=1)
        tqqq_month_data = tqqq_data.loc[month_start:month_end]
        sqqq_month_data = sqqq_data.loc[month_start:month_end]
        #Test if download is working #commented out code
        # print(tqqq_month_data)
        # print(sqqq_month_data)
        #Find the ATM strike price for TQQQ and SQQQ
        tqqq_close = tqqq_month_data['Close']
        tqqq_strike_price = round(tqqq_close / spread_width) * spread_width
        sqqq_close = sqqq_month_data['Close']
        sqqq_strike_price = round(sqqq_close / spread_width) * spread_width
         # Buy the call and put spreads at the mid-market rate
        tqqq_ask = tqqq_month_data['High'][tqqq_month_data['Strike'] == tqqq_strike_price].values[0]
        tqqq_bid = tqqq_month_data['Low'][tqqq_month_data['Strike'] == tqqq_strike_price].values[0]
        tqqq_mid = (tqqq_ask + tqqq_bid) / 2
        sqqq_ask = sqqq_month_data['High'][sqqq_month_data['Strike'] == sqqq_strike_price].values[0]
        sqqq_bid = sqqq_month_data['Low'][sqqq_month_data['Strike'] == sqqq_strike_price].values[0]
        sqqq_mid = (sqqq_ask + sqqq_bid) / 2
        tqqq_call_buy_price = tqqq_mid
        tqqq_put_buy_price = tqqq_mid
        sqqq_put_buy_price = sqqq_mid 
        tqqq_call_sell_price = tqqq_month_data['Low'][tqqq_month_data['Strike'] == tqqq_strike_price + spread_width].values
        if len(tqqq_call_sell_price) > 0:
            tqqq_call_sell_price = tqqq_call_sell_price[0]
        else:
            # handle the case where the filter did not match any rows
            tqqq_call_sell_price = 0.0  # set some default value        
        tqqq_put_sell_price = sqqq_month_data['Low'][sqqq_month_data['Strike'] == sqqq_strike_price - spread_width].values
        if len(tqqq_put_sell_price) > 0:
            tqqq_put_sell_price = tqqq_put_sell_price[0]
        else:
            # handle the case where the filter did not match any rows
            tqqq_put_sell_price = 0.0  # set some default value 
           
        sqqq_call_sell_price = sqqq_month_data['Low'][sqqq_month_data['Strike'] == sqqq_strike_price + spread_width].values
        if len(sqqq_call_sell_price) > 0:
            sqqq_call_sell_price = sqqq_call_sell_price[0]
        else:
            # handle the case where the filter did not match any rows
            sqqq_call_sell_price = 0.0  # set some default value 

        sqqq_put_sell_price = sqqq_month_data['Low'][sqqq_month_data['Strike'] == sqqq_strike_price - spread_width].values
        if len(sqqq_put_sell_price) > 0:
            sqqq_put_sell_price = sqqq_put_sell_price[0]
        else:
            # handle the case where the filter did not match any rows
            sqqq_put_sell_price = 0.0  # set some default value 
        #tqqq_put_sell_price = sqqq_month_data['Low'][sqqq_month_data['Strike'] == sqqq_strike_price - spread_width].values[0] 
        # Record the trade in the portfolio
        tqqq_call_quantity = int(initial_portfolio_value / tqqq_call_buy_price)
        sqqq_put_quantity = int(initial_portfolio_value / sqqq_put_buy_price)
        tqqq_call_profit_loss = calculate_profit_loss(tqqq_call_quantity, tqqq_call_buy_price, tqqq_call_sell_price)
        tqqq_put_quantity = int(initial_portfolio_value / tqqq_put_buy_price)
        tqqq_put_profit_loss = calculate_profit_loss(tqqq_put_quantity, tqqq_put_buy_price, tqqq_put_sell_price)
        total_cost = (tqqq_call_buy_price + sqqq_put_buy_price)
        # Calculate the total profit/loss for this trade
        total_profit_loss = tqqq_call_profit_loss + tqqq_put_profit_loss
        # Update the portfolio value
        initial_portfolio_value += total_profit_loss
        portfolio_values.append(initial_portfolio_value)    
        # Iterate over weeks
        # # Append row to portfolio dataframe        
        portfolio_df = pd.concat([portfolio_df, pd.DataFrame({'Week End Date': expiration_date,                                         
                                        'TQQQ Call Sell Price': tqqq_call_sell_price,                                        
                                        'SQQQ Put Sell Price': sqqq_put_sell_price, 
                                        'Total Cost': total_cost, 
                                        'Total P/L': total_profit_loss}, index=[i+1])])
        i +=1
        # Print the trade details
        print(f"Trade Date: {expiration_date}\n"
              f"TQQQ Call Buy Price: {tqqq_call_buy_price:.2f}\n"
              f"TQQQ Call Sell Price: {tqqq_call_sell_price:.2f}\n"
              f"TQQQ Call Quantity: {tqqq_call_quantity}\n"
              f"TQQQ Call P/L: {tqqq_call_profit_loss:.2f}\n"
              f"SQQQ Put Buy Price: {sqqq_put_buy_price:.2f}\n"
              f"SQQQ Put Sell Price: {sqqq_put_sell_price:.2f}\n"
              f"SQQQ Put Quantity: {sqqq_put_quantity}\n"
              f"Total P/L: {total_profit_loss:.2f}\n"
              f"Portfolio Value: {initial_portfolio_value:.2f}\n"
              f"-----------------------------------------")

        # Wait for a few seconds before executing the next trade
        #time.sleep(5)
# Print the final portfolio value
print(f"Final Portfolio Value: {initial_portfolio_value:.2f}")
# Out:
# Trade Date: 2020-01-17
# TQQQ Call Buy Price: 22.38
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 446
# TQQQ Call P/L: -9982.59
# SQQQ Put Buy Price: 540.88
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 18
# Total P/L: -19965.19
# Portfolio Value: -9965.19
# -----------------------------------------
# Trade Date: 2020-02-21
# TQQQ Call Buy Price: 24.20
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -411
# TQQQ Call P/L: 9945.69
# SQQQ Put Buy Price: 492.25
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -20
# Total P/L: 19891.37
# Portfolio Value: 9926.18
# -----------------------------------------
# Trade Date: 2020-03-20
# TQQQ Call Buy Price: 20.46
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 485
# TQQQ Call P/L: -9924.92
# SQQQ Put Buy Price: 546.75
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 18
# Total P/L: -19849.84
# Portfolio Value: -9923.65
# -----------------------------------------
# Trade Date: 2020-04-17
# TQQQ Call Buy Price: 10.79
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -919
# TQQQ Call P/L: 9918.31
# SQQQ Put Buy Price: 534.62
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -18
# Total P/L: 19836.62
# Portfolio Value: 9912.96
# -----------------------------------------
# Trade Date: 2020-05-15
# TQQQ Call Buy Price: 16.23
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 610
# TQQQ Call P/L: -9898.01
# SQQQ Put Buy Price: 309.75
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 32
# Total P/L: -19796.02
# Portfolio Value: -9883.06
# -----------------------------------------
# Trade Date: 2020-06-19
# TQQQ Call Buy Price: 20.73
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -476
# TQQQ Call P/L: 9869.26
# SQQQ Put Buy Price: 235.25
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -42
# Total P/L: 19738.53
# Portfolio Value: 9855.47
# -----------------------------------------
# Trade Date: 2020-07-17
# TQQQ Call Buy Price: 24.96
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 394
# TQQQ Call P/L: -9835.72
# SQQQ Put Buy Price: 184.88
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 53
# Total P/L: -19671.43
# Portfolio Value: -9815.97
# -----------------------------------------
# Trade Date: 2020-08-21
# TQQQ Call Buy Price: 30.90
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -317
# TQQQ Call P/L: 9794.90
# SQQQ Put Buy Price: 143.00
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -68
# Total P/L: 19589.81
# Portfolio Value: 9773.84
# -----------------------------------------
# Trade Date: 2020-09-18
# TQQQ Call Buy Price: 41.61
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 234
# TQQQ Call P/L: -9737.91
# SQQQ Put Buy Price: 103.38
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 94
# Total P/L: -19475.82
# Portfolio Value: -9701.98
# -----------------------------------------
# Trade Date: 2020-10-16
# TQQQ Call Buy Price: 33.98
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -285
# TQQQ Call P/L: 9684.66
# SQQQ Put Buy Price: 114.77
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -84
# Total P/L: 19369.31
# Portfolio Value: 9667.33
# -----------------------------------------
# Trade Date: 2020-11-20
# TQQQ Call Buy Price: 29.46
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 328
# TQQQ Call P/L: -9663.70
# SQQQ Put Buy Price: 124.32
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 77
# Total P/L: -19327.40
# Portfolio Value: -9660.07
# -----------------------------------------
# Trade Date: 2020-12-18
# TQQQ Call Buy Price: 40.88
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -236
# TQQQ Call P/L: 9647.98
# SQQQ Put Buy Price: 85.45
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -113
# Total P/L: 19295.95
# Portfolio Value: 9635.88
# -----------------------------------------
# Trade Date: 2021-01-15
# TQQQ Call Buy Price: 43.90
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 219
# TQQQ Call P/L: -9614.65
# SQQQ Put Buy Price: 78.58
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 122
# Total P/L: -19229.30
# Portfolio Value: -9593.41
# -----------------------------------------
# Trade Date: 2021-02-19
# TQQQ Call Buy Price: 47.44
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -202
# TQQQ Call P/L: 9583.38
# SQQQ Put Buy Price: 70.02
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -136
# Total P/L: 19166.77
# Portfolio Value: 9573.36
# -----------------------------------------
# Trade Date: 2021-03-19
# TQQQ Call Buy Price: 47.38
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 202
# TQQQ Call P/L: -9569.75
# SQQQ Put Buy Price: 67.80
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 141
# Total P/L: -19139.50
# Portfolio Value: -9566.14
# -----------------------------------------
# Trade Date: 2021-04-16
# TQQQ Call Buy Price: 47.61
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -200
# TQQQ Call P/L: 9522.50
# SQQQ Put Buy Price: 62.75
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -152
# Total P/L: 19045.00
# Portfolio Value: 9478.86
# -----------------------------------------
# Trade Date: 2021-05-21
# TQQQ Call Buy Price: 53.73
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 176
# TQQQ Call P/L: -9456.48
# SQQQ Put Buy Price: 54.55
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 173
# Total P/L: -18912.96
# Portfolio Value: -9434.10
# -----------------------------------------
# Trade Date: 2021-06-18
# TQQQ Call Buy Price: 51.15
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -184
# TQQQ Call P/L: 9411.14
# SQQQ Put Buy Price: 55.50
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -169
# Total P/L: 18822.28
# Portfolio Value: 9388.18
# -----------------------------------------
# Trade Date: 2021-07-16
# TQQQ Call Buy Price: 60.95
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 154
# TQQQ Call P/L: -9385.92
# SQQQ Put Buy Price: 45.95
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 204
# Total P/L: -18771.83
# Portfolio Value: -9383.65
# -----------------------------------------
# Trade Date: 2021-08-20
# TQQQ Call Buy Price: 66.80
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -140
# TQQQ Call P/L: 9352.35
# SQQQ Put Buy Price: 41.45
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -226
# Total P/L: 18704.70
# Portfolio Value: 9321.05
# -----------------------------------------
# Trade Date: 2021-09-17
# TQQQ Call Buy Price: 75.72
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 123
# TQQQ Call P/L: -9313.87
# SQQQ Put Buy Price: 36.17
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 257
# Total P/L: -18627.74
# Portfolio Value: -9306.69
# -----------------------------------------
# Trade Date: 2021-10-15
# TQQQ Call Buy Price: 62.21
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -149
# TQQQ Call P/L: 9269.66
# SQQQ Put Buy Price: 43.20
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -215
# Total P/L: 18539.32
# Portfolio Value: 9232.63
# -----------------------------------------
# Trade Date: 2021-11-19
# TQQQ Call Buy Price: 77.53
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 119
# TQQQ Call P/L: -9225.77
# SQQQ Put Buy Price: 34.02
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 271
# Total P/L: -18451.54
# Portfolio Value: -9218.91
# -----------------------------------------
# Trade Date: 2021-12-17
# TQQQ Call Buy Price: 81.52
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -113
# TQQQ Call P/L: 9212.04
# SQQQ Put Buy Price: 31.62
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -291
# Total P/L: 18424.08
# Portfolio Value: 9205.18
# -----------------------------------------
# Trade Date: 2022-01-21
# TQQQ Call Buy Price: 84.14
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 109
# TQQQ Call P/L: -9171.26
# SQQQ Put Buy Price: 29.25
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 314
# Total P/L: -18342.52
# Portfolio Value: -9137.34
# -----------------------------------------
# Trade Date: 2022-02-18
# TQQQ Call Buy Price: 61.54
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -148
# TQQQ Call P/L: 9107.92
# SQQQ Put Buy Price: 37.46
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -243
# Total P/L: 18215.84
# Portfolio Value: 9078.50
# -----------------------------------------
# Trade Date: 2022-03-18
# TQQQ Call Buy Price: 50.91
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 178
# TQQQ Call P/L: -9061.98
# SQQQ Put Buy Price: 41.98
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 216
# Total P/L: -18123.96
# Portfolio Value: -9045.46
# -----------------------------------------
# Trade Date: 2022-04-15
# TQQQ Call Buy Price: 57.61
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -157
# TQQQ Call P/L: 9044.77
# SQQQ Put Buy Price: 33.99
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -266
# Total P/L: 18089.54
# Portfolio Value: 9044.08
# -----------------------------------------
# Trade Date: 2022-05-20
# TQQQ Call Buy Price: 36.70
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 246
# TQQQ Call P/L: -9029.43
# SQQQ Put Buy Price: 48.73
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 185
# Total P/L: -18058.86
# Portfolio Value: -9014.78
# -----------------------------------------
# Trade Date: 2022-06-17
# TQQQ Call Buy Price: 32.99
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -273
# TQQQ Call P/L: 9006.27
# SQQQ Put Buy Price: 47.44
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -190
# Total P/L: 18012.54
# Portfolio Value: 8997.76
# -----------------------------------------
# Trade Date: 2022-07-15
# TQQQ Call Buy Price: 23.80
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 378
# TQQQ Call P/L: -8996.40
# SQQQ Put Buy Price: 59.10
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 152
# Total P/L: -17992.80
# Portfolio Value: -8995.04
# -----------------------------------------
# Trade Date: 2022-08-19
# TQQQ Call Buy Price: 33.43
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -269
# TQQQ Call P/L: 8992.67
# SQQQ Put Buy Price: 39.75
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -226
# Total P/L: 17985.34
# Portfolio Value: 8990.29
# -----------------------------------------
# Trade Date: 2022-09-16
# TQQQ Call Buy Price: 26.98
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 333
# TQQQ Call P/L: -8982.68
# SQQQ Put Buy Price: 46.72
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 192
# Total P/L: -17965.35
# Portfolio Value: -8975.06
# -----------------------------------------
# Trade Date: 2022-10-21
# TQQQ Call Buy Price: 20.19
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -444
# TQQQ Call P/L: 8962.14
# SQQQ Put Buy Price: 58.47
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -153
# Total P/L: 17924.28
# Portfolio Value: 8949.22
# -----------------------------------------
# Trade Date: 2022-11-18
# TQQQ Call Buy Price: 21.04
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 425
# TQQQ Call P/L: -8942.00
# SQQQ Put Buy Price: 51.65
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 173
# Total P/L: -17884.00
# Portfolio Value: -8934.78
# -----------------------------------------
# Trade Date: 2022-12-16
# TQQQ Call Buy Price: 23.59
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -378
# TQQQ Call P/L: 8917.02
# SQQQ Put Buy Price: 41.45
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -215
# Total P/L: 17834.04
# Portfolio Value: 8899.26
# -----------------------------------------
# Trade Date: 2023-01-20
# TQQQ Call Buy Price: 17.26
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 515
# TQQQ Call P/L: -8886.33
# SQQQ Put Buy Price: 54.12
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 164
# Total P/L: -17772.65
# Portfolio Value: -8873.39
# -----------------------------------------
# Trade Date: 2023-02-17
# TQQQ Call Buy Price: 23.66
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -375
# TQQQ Call P/L: 8870.63
# SQQQ Put Buy Price: 38.06
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -233
# Total P/L: 17741.25
# Portfolio Value: 8867.87
# -----------------------------------------
# Trade Date: 2023-03-17
# TQQQ Call Buy Price: 21.79
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: 406
# TQQQ Call P/L: -8846.74
# SQQQ Put Buy Price: 39.73
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: 223
# Total P/L: -17693.48
# Portfolio Value: -8825.61
# -----------------------------------------
# Trade Date: 2023-04-21
# TQQQ Call Buy Price: 27.73
# TQQQ Call Sell Price: 0.00
# TQQQ Call Quantity: -318
# TQQQ Call P/L: 8816.55
# SQQQ Put Buy Price: 29.91
# SQQQ Put Sell Price: 0.00
# SQQQ Put Quantity: -295
# Total P/L: 17633.10
# Portfolio Value: 8807.49
# -----------------------------------------
# Final Portfolio Value: 8807.49

# %% [markdown]
# Plot the portfolio values over time

# %%
# Plot the portfolio values over time
portfolio_data = pd.DataFrame(portfolio_values, columns=['Value'])
portfolio_data.plot(figsize=(10,5), title='Portfolio Value Over Time')
# print portfolio
portfolio_df
# Out:
#    Week End Date  TQQQ Call Sell Price  SQQQ Put Sell Price  Total Cost  \
# 1     2020-01-17                   0.0                  0.0  563.257500
# 2     2020-02-21                   0.0                  0.0  516.448750
# 3     2020-03-20                   0.0                  0.0  567.213750
# 4     2020-04-17                   0.0                  0.0  545.417500
# 5     2020-05-15                   0.0                  0.0  325.976250
# 6     2020-06-19                   0.0                  0.0  255.983749
# 7     2020-07-17                   0.0                  0.0  209.838750
# 8     2020-08-21                   0.0                  0.0  173.898749
# 9     2020-09-18                   0.0                  0.0  144.990000
# 10    2020-10-16                   0.0                  0.0  148.756248
# 11    2020-11-20                   0.0                  0.0  153.787497
# 12    2020-12-18                   0.0                  0.0  126.331251
# 1     2021-01-15                   0.0                  0.0  122.477501
# 2     2021-02-19                   0.0                  0.0  117.467497
# 3     2021-03-19                   0.0                  0.0  115.174999
# 4     2021-04-16                   0.0                  0.0  110.362499
# 5     2021-05-21                   0.0                  0.0  108.279999
# 6     2021-06-18                   0.0                  0.0  106.647501
# 7     2021-07-16                   0.0                  0.0  106.897501
# 8     2021-08-20                   0.0                  0.0  108.252502
# 9     2021-09-17                   0.0                  0.0  111.897503
# 10    2021-10-15                   0.0                  0.0  105.412498
# 11    2021-11-19                   0.0                  0.0  111.552496
# 12    2021-12-17                   0.0                  0.0  113.147499
# 1     2022-01-21                   0.0                  0.0  113.389999
# 2     2022-02-18                   0.0                  0.0   98.999998
# 3     2022-03-18                   0.0                  0.0   92.890001
# 4     2022-04-15                   0.0                  0.0   91.600000
# 5     2022-05-20                   0.0                  0.0   85.439999
# 6     2022-06-17                   0.0                  0.0   80.434999
# 7     2022-07-15                   0.0                  0.0   82.905000
# 8     2022-08-19                   0.0                  0.0   73.179998
# 9     2022-09-16                   0.0                  0.0   73.695000
# 10    2022-10-21                   0.0                  0.0   78.650001
# 11    2022-11-18                   0.0                  0.0   72.694999
# 12    2022-12-16                   0.0                  0.0   65.045000
# 1     2023-01-20                   0.0                  0.0   71.380000
# 2     2023-02-17                   0.0                  0.0   61.710001
# 3     2023-03-17                   0.0                  0.0   61.520000
# 4     2023-04-21                   0.0                  0.0   57.640000
#
#        Total P/L
# 1  -19965.189728
# 2   19891.372908
# 3  -19849.837389
# 4   19836.615035
# 5  -19796.024628
# 6   19738.529419
# 7  -19671.434910
# 8   19589.807089
# 9  -19475.819893
# 10  19369.312935
# 11 -19327.399750
# 12  19295.950180
# 1  -19229.295067
# 2   19166.769661
# 3  -19139.500000
# 4   19044.999695
# 5  -18912.959839
# 6   18822.280365
# 7  -18771.830070
# 8   18704.700470
# 9  -18627.735901
# 10  18539.324318
# 11 -18451.544128
# 12  18424.084793
# 1  -18342.519867
# 2   18215.839706
# 3  -18123.959946
# 4   18089.540192
# 5  -18058.859962
# 6   18012.539875
# 7  -17992.800144
# 8   17985.339138
# 9  -17965.350254
# 10  17924.280373
# 11 -17883.999968
# 12  17834.040115
# 1  -17772.650118
# 2   17741.250515
# 3  -17693.479969
# 4   17633.100243
